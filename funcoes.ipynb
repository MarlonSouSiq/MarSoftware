# %%
# %%writefile modulo.py
def saudacoes(nome):
    """ Retorna uma saudação personalizada """
    return f"Ola, {nome}! Tudo bem "
PI=3.14
# Out:
# Overwriting modulo.py

# %%
import modulo
# se fizer from modulo import saudacoes,pi ,,,, não prcisa chamar com modulo.

# %%
print(modulo.saudacoes("Mundo"))
# Out:
# Ola, Mundo! Tudo bem

# %%
print(modulo.PI)
# Out:
# 3.14
